# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test_X = pd.read_csv('test_X.csv')
display(test_X)
test_y = pd.read_csv('test_y.csv')
display(test_y)
train_X = pd.read_csv('train_X.csv')
display(train_X)
train_y = pd.read_csv('train_y.csv')
display(train_y)
val_X = pd.read_csv('val_X.csv')
display(val_X)
val_y = pd.read_csv('val_y.csv')
display(val_y)
# Out:
#     MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0       228.969       239.541       113.201         0.00238          0.000010
# 1       116.682       131.111       111.555         0.01050          0.000090
# 2       110.739       113.597       100.139         0.00356          0.000030
# 3       128.940       479.697        88.251         0.00581          0.000050
# 4       149.689       160.368       133.608         0.00257          0.000020
# 5       202.266       211.604       197.079         0.00180          0.000009
# 6        95.730       132.068        91.754         0.00551          0.000060
# 7       209.144       237.494       109.379         0.00282          0.000010
# 8       237.323       243.709       229.256         0.00303          0.000010
# 9       199.228       209.512       192.091         0.00241          0.000010
# 10      176.281       227.381       125.610         0.00520          0.000030
# 11      241.404       248.834       232.483         0.00281          0.000010
# 12      229.401       252.221       221.156         0.00205          0.000009
# 13       91.904       115.871        86.292         0.00540          0.000060
# 14      237.226       247.326       225.227         0.00298          0.000010
# 15       95.385       102.145        90.264         0.00608          0.000060
# 16      116.388       129.038       108.970         0.00346          0.000030
# 17      214.289       260.277        77.973         0.00567          0.000030
# 18      129.336       139.867       118.604         0.00490          0.000040
# 19      155.358       227.383        80.055         0.00310          0.000020
# 20       88.333       112.240        84.072         0.00505          0.000060
# 21      120.080       139.710       111.208         0.00405          0.000030
# 22      117.226       123.925       106.656         0.00417          0.000040
# 23      198.458       219.290       148.691         0.00376          0.000020
# 24      171.041       208.313        75.501         0.00455          0.000030
# 25      242.852       255.034       227.911         0.00225          0.000009
# 26      174.688       240.005        74.287         0.01360          0.000080
# 27      115.380       123.109       108.634         0.00332          0.000030
# 28      237.323       243.709       229.256         0.00303          0.000010
# 29      114.554       126.778        91.121         0.00651          0.000060
# 30      116.879       131.897       108.153         0.00788          0.000070
# 31      127.930       138.752       112.173         0.00605          0.000050
# 32      119.056       125.213        86.795         0.00346          0.000030
# 33      117.274       129.916       110.402         0.00752          0.000060
# 34      124.445       135.069       117.495         0.00431          0.000030
# 35      126.144       154.284        97.543         0.00975          0.000080
# 36      201.464       210.565       195.708         0.00198          0.000010
# 37      116.848       217.552        99.503         0.00531          0.000050
# 38      119.100       128.442        88.833         0.00692          0.000060
# 39      157.447       163.267       149.605         0.00369          0.000020
# 40      201.774       262.707        78.228         0.00694          0.000030
# 41      148.272       164.989       142.299         0.00459          0.000030
# 42      176.858       205.560        75.344         0.00747          0.000040
# 43      208.083       253.792        91.802         0.00757          0.000040
# 44       96.106       108.664        84.510         0.00694          0.000070
# 45      166.888       198.966        79.512         0.00638          0.000040
# 46      157.821       172.975        68.401         0.00358          0.000020
# 47      159.116       168.913       144.811         0.00342          0.000020
# 48      197.569       217.627        90.794         0.00803          0.000040
# 49      174.688       240.005        74.287         0.01360          0.000080
# 50      210.141       232.706       185.258         0.00534          0.000030
# 51      112.876       148.826       106.981         0.00500          0.000040
# 52      204.664       221.300       189.621         0.00841          0.000040
# 53      237.226       247.326       225.227         0.00298          0.000010
# 54      114.563       119.167        86.647         0.00327          0.000030
# 55      260.105       264.919       237.303         0.00339          0.000010
# 56      223.365       238.987        98.664         0.00264          0.000010
# 57      146.845       208.701        81.737         0.00496          0.000030
#
#     MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       0
# 16       1
# 17       1
# 18       0
# 19       0
# 20       1
# 21       1
# 22       1
# 23       0
# 24       0
# 25       1
# 26       1
# 27       0
# 28       0
# 29       1
# 30       0
# 31       0
# 32       0
# 33       0
# 34       0
# 35       0
# 36       1
# 37       0
# 38       1
# 39       1
# 40       0
# 41       1
# 42       0
# 43       0
# 44       0
# 45       1
# 46       1
# 47       0
# 48       0
# 49       0
# 50       1
# 51       0
# 52       0
# 53       1
# 54       1
# 55       0
# 56       1
# 57       1

# %% [markdown]
# # Experimenting with Scalers and Transformers

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PowerTransformer

std_scaler = StandardScaler()
X_train_std = std_scaler.fit_transform(train_X)
X_val_std = std_scaler.transform(val_X)
X_test_std = std_scaler.transform(test_X)
display(X_train_std)

minmax_scaler = MinMaxScaler()
X_train_mm = minmax_scaler.fit_transform(train_X)
X_val_mm = minmax_scaler.transform(val_X)
X_test_mm = minmax_scaler.transform(test_X)
display(X_train_mm)

rob_scaler = RobustScaler()
X_train_rob = rob_scaler.fit_transform(train_X)
X_val_rob = rob_scaler.transform(val_X)
X_test_rob = rob_scaler.transform(test_X)
display(X_train_rob)

pow_transform = PowerTransformer(method='yeo-johnson')
X_train_pow = pow_transform.fit_transform(train_X)
X_val_pow = pow_transform.transform(val_X)
X_test_pow = pow_transform.transform(test_X)
display(X_train_pow)
# Out:
# array([[ 1.90037667,  0.48124361,  1.93489104, ..., -0.5388888 ,
#         -1.13822344, -1.15287837],
#        [ 1.74530562,  0.44800308,  0.94958006, ..., -0.05131468,
#         -0.75298253, -1.03807883],
#        [ 0.74654666, -0.03589258,  1.19129455, ..., -0.50147023,
#         -2.34102401, -1.48257   ],
#        ...,
#        [-0.32261252, -0.50161831,  0.26188479, ..., -0.26407626,
#         -0.13486036, -0.42530136],
#        [ 0.66635567, -0.05539912,  1.11775363, ..., -0.38336978,
#         -0.55755105, -1.22812299],
#        [ 1.13274454,  0.15606371,  1.36001033, ..., -1.31656825,
#         -0.09692261, -0.85940737]])
# array([[1.        , 0.33205166, 0.98925121, ..., 0.32821604, 0.23035006,
#         0.06430447],
#        [0.95365013, 0.32504365, 0.67538315, ..., 0.42191365, 0.30412809,
#         0.08669547],
#        [0.65512666, 0.22302517, 0.75238062, ..., 0.3354068 , 0.        ,
#         0.        ],
#        ...,
#        [0.33556095, 0.12483741, 0.45631973, ..., 0.38102704, 0.42250555,
#         0.20621422],
#        [0.63115802, 0.21891266, 0.72895437, ..., 0.35810229, 0.34155546,
#         0.04962844],
#        [0.77055905, 0.26349482, 0.80612456, ..., 0.17876861, 0.42977107,
#         0.12154432]])
# array([[ 1.25048258,  0.59913269,  1.52526107, ..., -0.36047003,
#         -0.76393587, -0.71751158],
#        [ 1.16044021,  0.56653019,  0.8887929 , ...,  0.05942623,
#         -0.47342507, -0.62570115],
#        [ 0.58050847,  0.09192252,  1.04492998, ..., -0.32824536,
#         -1.67096974, -0.98118103],
#        ...,
#        [-0.04030132, -0.36486397,  0.44457157, ..., -0.12380293,
#         -0.00729813, -0.13563503],
#        [ 0.53394539,  0.0727904 ,  0.99742573, ..., -0.22653787,
#         -0.32604987, -0.77768814],
#        [ 0.80475518,  0.28019436,  1.15391306, ..., -1.03020349,
#          0.02131079, -0.48280943]])
# array([[ 1.58468905,  0.86188787,  1.54365857, ..., -0.48415838,
#         -1.17430919, -1.5958223 ],
#        [ 1.49979693,  0.83317831,  1.08937694, ...,  0.04243685,
#         -0.73071269, -1.34598987],
#        [ 0.85163269,  0.32458592,  1.2210041 , ..., -0.44193546,
#         -2.75193151, -2.42177024],
#        ...,
#        [-0.14108694, -0.41364725,  0.60239267, ..., -0.18120201,
#         -0.06941285, -0.27101892],
#        [ 0.79017767,  0.29967356,  1.18264211, ..., -0.3107032 ,
#         -0.51525867, -1.7695153 ],
#        [ 1.12587431,  0.54932994,  1.30400699, ..., -1.43812529,
#         -0.0306693 , -0.99060418]])

# %%
fig,ax = plt.subplots(2,2, figsize=(8,8))
ax[0,0].hist(X_train_std)
ax[0,0].set_title('StandardScaler')
ax[0,1].hist(X_train_mm)
ax[0,1].set_title('MinMaxScaler')
ax[1,0].hist(X_train_rob)
ax[1,0].set_title('RobustScaler')
ax[1,1].hist(X_train_pow)
ax[1,1].set_title('PowerTransformer')
plt.show()

# %% [markdown]
# # Experimenting with Isolation Forests for Anomaly Detection

# %%
#use the isolation forest model to search for anomalies on the scaled/transformed data
from sklearn.ensemble import IsolationForest

# create the model
clf = IsolationForest(random_state=42, contamination=0.01)
#clf = IsolationForest(random_state=42, contamination=0.02)
anomaly_threshold = -0.5

# Fit the model to the StandardScaler data
clf.fit(X_train_std)

# create a column for the predictions of the StandardScaler data
df['anomaly_score'] = clf.decision_function(X_train_std)
df['outlier'] = clf.predict(X_train_std)
std_anomaly_test = clf.decision_function(X_test_std)
std_anomalies_test = std_anomaly_test < anomaly_threshold
std_anomaly_val = clf.decision_function(X_val_std)
std_anomalies_val = std_anomaly_val < anomaly_threshold
std_train_out = df.loc[df['outlier'] == -1].index

# show the number of outliers for the StandardScaler data
print('Standard Scaler')
print(df['outlier'].value_counts())
print(std_anomalies_test)
print(std_anomalies_val)
display(df.loc[df['outlier'] == -1])

# Fit the model to the MinMaxScaler data
clf.fit(X_train_mm)

# create a column for the predictions of the MinMaxScaler data
df['anomaly_score'] = clf.decision_function(X_train_mm)
df['outlier'] = clf.predict(X_train_mm)
mm_anomaly_test = clf.decision_function(X_test_mm)
mm_anomalies_test = mm_anomaly_test < anomaly_threshold
mm_anomaly_val = clf.decision_function(X_val_mm)
mm_anomalies_val = mm_anomaly_val < anomaly_threshold
mm_train_out = df.loc[df['outlier'] == -1].index

# show the number of outliers for the MinMaxScaler data
print('MinMaxScaler')
print(df['outlier'].value_counts())
print(mm_anomalies_test)
print(mm_anomalies_val)
display(df.loc[df['outlier'] == -1])

# Fit the model to the RobustScaler data
clf.fit(X_train_rob)

# create a column for the predictions of the RobustScaler data
df['anomaly_score'] = clf.decision_function(X_train_rob)
df['outlier'] = clf.predict(X_train_rob)
rob_anomaly_test = clf.decision_function(X_test_rob)
rob_anomalies_test = rob_anomaly_test < anomaly_threshold
rob_anomaly_val = clf.decision_function(X_val_rob)
rob_anomalies_val = rob_anomaly_val < anomaly_threshold
rob_train_out = df.loc[df['outlier'] == -1].index

# show the number of outliers for the RobustScaler data
print('RobustScaler')
print(df['outlier'].value_counts())
print(rob_anomalies_test)
print(rob_anomalies_val)
display(df.loc[df['outlier'] == -1])

# Fit the model to the PowerTransformer data
clf.fit(X_train_pow)

# create a column for the predictions for the PowerTransformer data
df['anomaly_score'] = clf.decision_function(X_train_pow)
df['outlier'] = clf.predict(X_train_pow)
pow_anomaly_test = clf.decision_function(X_test_pow)
pow_anomalies_test = pow_anomaly_test < anomaly_threshold
pow_anomaly_val = clf.decision_function(X_val_pow)
pow_anomalies_val = pow_anomaly_val < anomaly_threshold
pow_train_out = df.loc[df['outlier']==-1].index

# show the number of outliers of the PowerTransformer data
print('PowerTransformer')
print(df['outlier'].value_counts())
print(pow_anomalies_test)
print(pow_anomalies_val)
display(df.loc[df['outlier']==-1])

# Remove the outliers for each type of scaled/transformed data
X_train_no_outliers_std = np.delete(X_train_std, std_train_out, axis=0)
y_train_no_outliers_std = np.delete(train_y, std_train_out)

X_train_no_outliers_mm = np.delete(X_train_mm, mm_train_out, axis=0)
y_train_no_outliers_mm = np.delete(train_y, mm_train_out)

X_train_no_outliers_rob = np.delete(X_train_rob, rob_train_out, axis=0)
y_train_no_outliers_rob = np.delete(train_y, rob_train_out)

X_train_no_outliers_pow = np.delete(X_train_pow, pow_train_out, axis=0)
y_train_no_outliers_pow = np.delete(train_y, pow_train_out)
# Out:
# Standard Scaler
# outlier
#  1    174
# -1      2
# Name: count, dtype: int64
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 43       125.641       141.068       116.346         0.03316
# 111      192.818       224.429       168.793         0.03107
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 43            0.00026   0.02144   0.01522     0.06433       0.09178
# 111           0.00016   0.01800   0.01958     0.05401       0.11908
#
#      MDVP:Shimmer(dB)  ...    HNR      RPDE       DFA   spread1   spread2  \
# 43              0.891  ...  8.867  0.671299  0.656846 -3.700544  0.260481
# 111             1.302  ...  8.441  0.625866  0.768320 -2.434031  0.450493
#
#            D2       PPE  status  anomaly_score  outlier
# 43   2.991063  0.370961       1      -0.001802       -1
# 111  3.079221  0.527367       1      -0.031077       -1
#
# [2 rows x 25 columns]
# MinMaxScaler
# outlier
#  1    174
# -1      2
# Name: count, dtype: int64
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 43       125.641       141.068       116.346         0.03316
# 111      192.818       224.429       168.793         0.03107
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 43            0.00026   0.02144   0.01522     0.06433       0.09178
# 111           0.00016   0.01800   0.01958     0.05401       0.11908
#
#      MDVP:Shimmer(dB)  ...    HNR      RPDE       DFA   spread1   spread2  \
# 43              0.891  ...  8.867  0.671299  0.656846 -3.700544  0.260481
# 111             1.302  ...  8.441  0.625866  0.768320 -2.434031  0.450493
#
#            D2       PPE  status  anomaly_score  outlier
# 43   2.991063  0.370961       1      -0.001802       -1
# 111  3.079221  0.527367       1      -0.031077       -1
#
# [2 rows x 25 columns]
# RobustScaler
# outlier
#  1    174
# -1      2
# Name: count, dtype: int64
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 43       125.641       141.068       116.346         0.03316
# 111      192.818       224.429       168.793         0.03107
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 43            0.00026   0.02144   0.01522     0.06433       0.09178
# 111           0.00016   0.01800   0.01958     0.05401       0.11908
#
#      MDVP:Shimmer(dB)  ...    HNR      RPDE       DFA   spread1   spread2  \
# 43              0.891  ...  8.867  0.671299  0.656846 -3.700544  0.260481
# 111             1.302  ...  8.441  0.625866  0.768320 -2.434031  0.450493
#
#            D2       PPE  status  anomaly_score  outlier
# 43   2.991063  0.370961       1      -0.001802       -1
# 111  3.079221  0.527367       1      -0.031077       -1
#
# [2 rows x 25 columns]
# PowerTransformer
# outlier
#  1    174
# -1      2
# Name: count, dtype: int64
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False]
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 2        203.184       211.526       196.160         0.00178
# 111      192.818       224.429       168.793         0.03107
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 2            0.000009   0.00094   0.00106     0.00283       0.00958
# 111          0.000160   0.01800   0.01958     0.05401       0.11908
#
#      MDVP:Shimmer(dB)  ...     HNR      RPDE       DFA   spread1   spread2  \
# 2               0.085  ...  33.047  0.340068  0.741899 -7.964984  0.163519
# 111             1.302  ...   8.441  0.625866  0.768320 -2.434031  0.450493
#
#            D2       PPE  status  anomaly_score  outlier
# 2    1.423287  0.044539       0      -0.061220       -1
# 111  3.079221  0.527367       1      -0.000208       -1
#
# [2 rows x 25 columns]

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(6, 6))
clf.fit(X_train_std)
predictions_std = clf.predict(X_train_std)

ax1.scatter(X_train_std[:, 0], X_train_std[:, 1], c=clf.decision_function(X_train_std), marker='.')
ax1.set_title('StandardScaler Anomalies')
ax2.plot(X_train_std[predictions_std==1][:,0], X_train_std[predictions_std==1][:,1], 'b.')
ax2.plot(X_train_std[predictions_std==-1][:,0], X_train_std[predictions_std==-1][:,-1], 'rx')
ax2.set_title('StandardScaler Anomalies')    

df = pd.DataFrame(dict(predicted_label=clf.predict(X_train_std), score=clf.decision_function(X_train_std)))
outliers = df[df['predicted_label'] == -1].values
inliers = df[df['predicted_label'] == 1].head(len(outliers)).values
std_scores = pd.DataFrame(np.concatenate([inliers, outliers], axis=1), 
             columns=['Inlier Label', 'Inline Score', 'Outlier Label', 'Outline Score'])
display(std_scores)
      
clf.fit(X_train_mm)
predictions_mm = clf.predict(X_train_mm)

ax3.scatter(X_train_mm[:, 0], X_train_mm[:, 1], c=clf.decision_function(X_train_mm), marker='.')
ax3.set_title('MinMaxScaler Anomalies')
ax4.plot(X_train_mm[predictions_mm==1][:,0], X_train_mm[predictions_mm==1][:,1], 'b.')
ax4.plot(X_train_mm[predictions_mm==-1][:,0], X_train_mm[predictions_mm==-1][:,-1], 'rx')
ax4.set_title('MinMaxScaler Anomalies')

plt.show()

df = pd.DataFrame(dict(predicted_label=clf.predict(X_train_mm), score=clf.decision_function(X_train_mm)))
outliers = df[df['predicted_label'] == -1].values
inliers = df[df['predicted_label'] == 1].head(len(outliers)).values
mm_scores = pd.DataFrame(np.concatenate([inliers, outliers], axis=1), 
             columns=['Inlier Label', 'Inline Score', 'Outlier Label', 'Outline Score'])
display(mm_scores)
# Out:
#    Inlier Label  Inline Score  Outlier Label  Outline Score
# 0           1.0      0.270177           -1.0      -0.001802
# 1           1.0      0.233540           -1.0      -0.031077
#    Inlier Label  Inline Score  Outlier Label  Outline Score
# 0           1.0      0.270177           -1.0      -0.001802
# 1           1.0      0.233540           -1.0      -0.031077

# %%
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(2, 2, figsize=(6, 6))

clf.fit(X_train_rob)
predictions_rob = clf.predict(X_train_rob)

ax1.scatter(X_train_rob[:, 0], X_train_std[:, 1], c=clf.decision_function(X_train_rob), marker='.')
ax1.set_title('RobustScaler Anomalies')
ax2.plot(X_train_rob[predictions_rob==1][:,0], X_train_rob[predictions_rob==1][:,1], 'b.')
ax2.plot(X_train_rob[predictions_rob==-1][:,0], X_train_rob[predictions_rob==-1][:,-1], 'rx')
ax2.set_title('RobustScaler Anomalies')

df = pd.DataFrame(dict(predicted_label=clf.predict(X_train_rob), score=clf.decision_function(X_train_rob)))
outliers = df[df['predicted_label'] == -1].values
inliers = df[df['predicted_label'] == 1].head(len(outliers)).values
rob_scores = pd.DataFrame(np.concatenate([inliers, outliers], axis=1), 
             columns=['Inlier Label', 'Inline Score', 'Outlier Label', 'Outline Score'])
display(rob_scores)

clf.fit(X_train_pow)
predictions_pow= clf.predict(X_train_pow)

ax3.scatter(X_train_pow[:, 0], X_train_std[:, 1], c=clf.decision_function(X_train_pow), marker='.')
ax3.set_title('PowerTransformer Anomalies')
ax4.plot(X_train_pow[predictions_pow==1][:,0], X_train_pow[predictions_pow==1][:,1], 'b.')
ax4.plot(X_train_pow[predictions_pow==-1][:,0], X_train_pow[predictions_pow==-1][:,-1], 'rx')
ax4.set_title('PowerTransformer Anomalies')
plt.show()

df = pd.DataFrame(dict(predicted_label=clf.predict(X_train_pow), score=clf.decision_function(X_train_pow)))
outliers = df[df['predicted_label'] == -1].values
inliers = df[df['predicted_label'] == 1].head(len(outliers)).values
pow_scores = pd.DataFrame(np.concatenate([inliers, outliers], axis=1), 
             columns=['Inlier Label', 'Inline Score', 'Outlier Label', 'Outline Score'])
display(pow_scores)
# Out:
#    Inlier Label  Inline Score  Outlier Label  Outline Score
# 0           1.0      0.270177           -1.0      -0.001802
# 1           1.0      0.233540           -1.0      -0.031077
#    Inlier Label  Inline Score  Outlier Label  Outline Score
# 0           1.0      0.137149           -1.0      -0.061220
# 1           1.0      0.043734           -1.0      -0.000208

# %% [markdown]
# # Experimenting with PCA for Dimensionality Reduction

# %% [markdown]
# ### Scalers Determined not to use

# %% [markdown]
# #### StandardScaler
#
# #use principal component analysis to determine categories for the data
# from sklearn.decomposition import PCA
#
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_std) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 2)
#
# #fit the model and transform the data
# transformed = pca.fit_transform(X_train_std)
#
# #create a dataframe of the transformed data
# df_ss = pd.DataFrame(transformed, columns=['x', 'y'])
# df_ss['status'] = train_y
#
# #create a scatterplot of the data
# sns.scatterplot(x='x', y='y', hue='status', data=df_ss)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()

# %% [markdown]
# #### StandardScaler no outliers
#
# #use principal component analysis to determine categories for the data
# from sklearn.decomposition import PCA
#
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_no_outliers_std) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 2)
#
# #fit the model and transform the data
# transformed = pca.fit_transform(X_train_no_outliers_std)
#
# #create a dataframe of the transformed data
# df_ss_no = pd.DataFrame(transformed, columns=['x', 'y'])
# df_ss_no['status'] = y_train_no_outliers_std
#
# #create a scatterplot of the data
# sns.scatterplot(x='x', y='y', hue='status', data=df_ss_no)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()

# %% [markdown]
# ### MinMaxScaler
#
# #use principal component analysis to determine catagories for the data
# from sklearn.decomposition import PCA
#
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_mm) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 2)
#
# #fit the model and transform the data
# transformed = pca.fit_transform(X_train_mm)
#
# #create a dataframe of the transformed data
# df_mm = pd.DataFrame(transformed, columns=['x', 'y'])
# df_mm['status'] = train_y
#
# #create a scatterplot of the data
# sns.scatterplot(x='x', y='y', hue='status', data=df_mm)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()

# %% [markdown]
# ### MinMaxScaler no outliers
#
# #use principal component analysis to determine catagories for the data
# from sklearn.decomposition import PCA
#
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_no_outliers_mm) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 2)
#
# #fit the model and transform the data
# transformed = pca.fit_transform(X_train_no_outliers_mm)
#
# #create a dataframe of the transformed data
# df_mm_no = pd.DataFrame(transformed, columns=['x', 'y'])
# df_mm_no['status'] = y_train_no_outliers_mm
#
# #create a scatterplot of the data
# sns.scatterplot(x='x', y='y', hue='status', data=df_mm_no)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()

# %% [markdown]
# ### RobustScaler PCA

# %% [markdown]
# #use principal component analysis to determine categories for the data
# from sklearn.decomposition import PCA
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_rob) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
#
# best_comp_rob = None
# max_expvar_rob = 0.0
#
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     if explained_variance > max_expvar_rob:
#         max_expvar_rob = explained_variance
#         best_comp_rob = n_components[i]
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 8)
#
# #fit the model and transform the data
# transformed_rob = pca.fit_transform(X_train_rob)
#
# #create a dataframe of the transformed data
# df_rob = pd.DataFrame(transformed_rob, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7','PC8'])
# df_rob['status'] = train_y
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='status', data=df_rob)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
# #show components relations with features:
# print(pd.DataFrame(pca.components_,columns=train_X.columns,index = ['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC-8']))

# %% [markdown]
# ### RobustScaler no outliers PCA

# %% [markdown]
# #use principal component analysis to determine categories for the data
# from sklearn.decomposition import PCA
#
#
# #test n_number of components to find the best fit for the data
# n_components = np.arange(1, 23)
# models = [PCA(n).fit(X_train_no_outliers_rob) for n in n_components]
#
# #plot the explained variance ratio for each number of components
# plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')
#
# best_comp_rob_no = None
# max_expvar_rob_no = 0.0
#
# for i, model in enumerate(models):
#     explained_variance = model.explained_variance_ratio_.sum()
#     if explained_variance > max_expvar_rob_no:
#         max_expvar_rob_no = explained_variance
#         best_comp_rob_no = n_components[i]
#     print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
# plt.xlabel('n_components')
# plt.ylabel('explained variance')
# plt.show()
#
#
# #create the model
# pca = PCA(n_components = 8)
#
# #fit the model and transform the data
# transformed_rob_no = pca.fit_transform(X_train_no_outliers_rob)
#
# #create a dataframe of the transformed data
# df_rob_no = pd.DataFrame(transformed_rob_no, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7','PC8'])
# df_rob_no['status'] = y_train_no_outliers_rob
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='status', data=df_rob_no)
#
# #make title
# plt.title('PCA Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
#
# #show components relations with features:
# print(pd.DataFrame(pca.components_,columns=train_X.columns,index = ['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC-8']))

# %% [markdown]
# ### PowerTransformer PCA

# %%
#use principal component analysis to determine catagories for the data
from sklearn.decomposition import PCA


#test n_number of components to find the best fit for the data
n_components = np.arange(1, 23)
models = [PCA(n).fit(X_train_pow) for n in n_components]

#plot the explained variance ratio for each number of components
plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')

best_comp_pow = None
max_expvar_pow = 0.0
for i, model in enumerate(models):
    explained_variance = model.explained_variance_ratio_.sum()
    if explained_variance > max_expvar_pow:
        max_expvar_pow = explained_variance
        best_comp_pow = n_components[i]
    print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
plt.xlabel('n_components')
plt.ylabel('explained variance')
plt.show()


#create the model
pca = PCA(n_components = 8)

#fit the model and transform the data
transformed_pow = pca.fit_transform(X_train_pow)

#create a dataframe of the transformed data
df_pow = pd.DataFrame(transformed_pow, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7','PC8'])
df_pow['status'] = train_y

#create a scatterplot of the data
sns.scatterplot(x='PC1', y='PC2', hue='status', data=df_pow)

#make title
plt.title('PCA Scatterplot')
plt.grid()
#add lines to thicken the 0 lines
plt.axhline(0, color='black')
plt.axvline(0, color='black')

#show the plot
plt.show()

#show components relations with features: 
print(pd.DataFrame(pca.components_,columns=train_X.columns,index = ['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC-8']))
# PC-7  0.059684  0.377381  0.002624  0.186982 -0.354523  0.029692
# PC-8 -0.087896  0.019941 -0.380542  0.528486 -0.029032 -0.425318
#
# [8 rows x 22 columns]

# %% [markdown]
# ### PowerTransformer no outliers PCA

# %%
#use principal component analysis to determine catagories for the data
from sklearn.decomposition import PCA


#test n_number of components to find the best fit for the data
n_components = np.arange(1, 23)
models = [PCA(n).fit(X_train_no_outliers_pow) for n in n_components]

#plot the explained variance ratio for each number of components
plt.plot(n_components, [m.explained_variance_ratio_.sum() for m in models], color='black')

best_comp_pow_no = None
max_expvar_pow_no = 0.0

for i, model in enumerate(models):
    explained_variance = model.explained_variance_ratio_.sum()
    if explained_variance > max_expvar_pow_no:
        max_expvar_pow_no = explained_variance
        best_comp_pow_no = n_components[i]
    print(f'Component {n_components[i]}: Explained Variance {explained_variance}')
plt.xlabel('n_components')
plt.ylabel('explained variance')
plt.show()


#create the model
pca = PCA(n_components = 8)

#fit the model and transform the data
transformed_pow_no = pca.fit_transform(X_train_no_outliers_pow)

#create a dataframe of the transformed data
df_pow_no = pd.DataFrame(transformed_pow_no, columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6','PC7','PC8'])
df_pow_no['status'] = y_train_no_outliers_pow

#create a scatterplot of the data
sns.scatterplot(x='PC1', y= 'PC2', hue='status', data=df_pow_no)

#make title
plt.title('PCA Scatterplot')
plt.grid()
#add lines to thicken the 0 lines
plt.axhline(0, color='black')
plt.axvline(0, color='black')

#show the plot
plt.show()

#show components relations with features: 
print(pd.DataFrame(pca.components_,columns=train_X.columns,index = ['PC-1','PC-2','PC-3','PC-4','PC-5','PC-6','PC-7','PC8']))
# Out:
# Component 1: Explained Variance 0.6059299135114773
# Component 2: Explained Variance 0.7365739472850836
# Component 3: Explained Variance 0.8040643188617147
# Component 4: Explained Variance 0.8587867305302328
# Component 5: Explained Variance 0.8977408244110943
# Component 6: Explained Variance 0.9268657790533776
# Component 7: Explained Variance 0.948781826029107
# Component 8: Explained Variance 0.9647647267417523
# Component 9: Explained Variance 0.975151751176148
# Component 10: Explained Variance 0.98344796152047
# Component 11: Explained Variance 0.9886582405558636
# Component 12: Explained Variance 0.9930159374798261
# Component 13: Explained Variance 0.9952072661397783
# Component 14: Explained Variance 0.9972583064072249
# Component 15: Explained Variance 0.9982394457486766
# Component 16: Explained Variance 0.9988595108453533
# Component 17: Explained Variance 0.9993806120610511
# Component 18: Explained Variance 0.9997143479615457
# Component 19: Explained Variance 0.9999633078087973
# Component 20: Explained Variance 0.999999646465391
# Component 21: Explained Variance 0.9999998759506629
# Component 22: Explained Variance 1.0
#       MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# PC-1    -0.105493     -0.055641     -0.147545        0.251925
# PC-2    -0.503587     -0.421408     -0.229356        0.025575
# PC-3     0.003984      0.343298     -0.318183        0.089110
# PC-4     0.083664      0.111515     -0.023412        0.273134
# PC-5     0.177017      0.029583      0.247593       -0.038481
# PC-6    -0.143426      0.023663     -0.676554       -0.145847
# PC-7     0.045803      0.736314     -0.190061       -0.015373
# PC8      0.205404     -0.188173     -0.380440        0.146618
#
#       MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# PC-1          0.242711  0.244183  0.254220    0.244172      0.253282
# PC-2          0.205304 -0.062182  0.009284   -0.062097     -0.116196
# PC-3          0.083478  0.036772  0.055569    0.036713     -0.216699
# PC-4          0.175157  0.357747  0.274514    0.358027     -0.136058
# PC-5         -0.068378 -0.089819 -0.061223   -0.089954      0.006561
# PC-6         -0.095287 -0.152106 -0.164639   -0.151450      0.098696
# PC-7         -0.038600 -0.056256  0.013924   -0.056200      0.067051
# PC8          -0.014888  0.047772 -0.095761    0.047718      0.008944
#
#       MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR       HNR  \
# PC-1          0.255470  ...  0.257199     0.242779  0.237433 -0.229372
# PC-2         -0.126355  ... -0.042602    -0.148292 -0.146889  0.203817
# PC-3         -0.183207  ... -0.126846    -0.276370  0.200767 -0.007404
# PC-4         -0.084655  ... -0.186454    -0.123285  0.047571  0.054073
# PC-5          0.002017  ...  0.035227    -0.009255 -0.113664  0.099495
# PC-6          0.097079  ...  0.124689     0.067977  0.024634  0.062981
# PC-7          0.078185  ...  0.081302     0.050332 -0.156041  0.181027
# PC8           0.064664  ... -0.066275     0.047220  0.267843  0.076485
#
#           RPDE       DFA   spread1   spread2        D2       PPE
# PC-1  0.153357  0.069681  0.224507  0.155821  0.143700  0.225413
# PC-2  0.062464  0.392474  0.192513  0.177505 -0.207278  0.195452
# PC-3  0.205461 -0.395827  0.233969  0.212650  0.279455  0.198112
# PC-4 -0.519924  0.213731 -0.058575 -0.323504 -0.072626 -0.040259
# PC-5 -0.438622  0.312500  0.172782  0.429253  0.560771  0.193692
# PC-6 -0.316629  0.000908 -0.014109 -0.405185  0.305442  0.003489
# PC-7  0.079872  0.384891  0.023638  0.171321 -0.370624  0.056658
# PC8  -0.070402  0.065060 -0.391453  0.534029 -0.058286 -0.428466
#
# [8 rows x 22 columns]

# %% [markdown]
# # Experimenting with Hierarchical Clustering for Feature Selection

# %% [markdown]
# ### RobustScaler HC

# %% [markdown]
# #create a heirarchical clustering model
# from sklearn.cluster import AgglomerativeClustering
# from scipy.cluster.hierarchy import dendrogram, linkage
#
# #find the optimal number of clusters
# n_clusters = range(2, 10)
# models = [AgglomerativeClustering(n).fit(X_train_rob) for n in n_clusters]
#
# #plot the silhouette scores
# from sklearn.metrics import silhouette_score
# scores = [silhouette_score(X_train_rob, m.labels_) for m in models]
# plt.plot(n_clusters, scores, color='black')
# plt.xlabel('n_clusters')
# plt.ylabel('score')
# plt.grid()
# plt.show()
#
# for i, clust_num in enumerate(n_clusters):
#     mean_score = scores[i].mean()
#     print(f"Cluster {clust_num}: Mean Silhouette Score: {mean_score}")
#
# #create the model
# hi_model = AgglomerativeClustering(n_clusters=2)
# #hi_model = AgglomerativeClustering(n_clusters=3)
#
# #fit the model
# hi_model.fit(X_train_rob)
#
# #create a column for the cluster
# df_rob['cluster'] = hi_model.labels_
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=df_rob)
#
# #make title
# plt.title('Hierarchical Clustering Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
# Z = linkage(X_train_rob, method='ward')
# #Z = linkage(X_train_rob, method='average')
# dendrogram(Z, labels=train_y.values)
# plt.title('Hierarichical Clustering Dendogram RobustScaler')
# plt.xlabel('Samples')
# plt.ylabel('Distance')
#
# print("Hierarchical Clustering-Agglomerative NMI Score for RobustScaler",
#       normalized_mutual_info_score(train_y, df_rob['cluster']))

# %% [markdown]
# ### RobustScaler no outliers HC

# %% [markdown]
# #create a heirarchical clustering model
# from sklearn.cluster import AgglomerativeClustering
# from scipy.cluster.hierarchy import dendrogram, linkage
#
# #find the optimal number of clusters
# n_clusters = range(2, 10)
# models = [AgglomerativeClustering(n).fit(X_train_no_outliers_rob) for n in n_clusters]
#
# #plot the silhouette scores
# from sklearn.metrics import silhouette_score
# scores = [silhouette_score(X_train_no_outliers_rob, m.labels_) for m in models]
# plt.plot(n_clusters, scores, color='black')
# plt.xlabel('n_clusters')
# plt.ylabel('score')
# plt.grid()
# plt.show()
#
# for i, clust_num in enumerate(n_clusters):
#     mean_score = scores[i].mean()
#     print(f"Cluster {clust_num}: Mean Silhouette Score: {mean_score}")
#
# #create the model
# hi_model = AgglomerativeClustering(n_clusters=2)
# #hi_model = AgglomerativeClustering(n_clusters=3)
#
# #fit the model
# hi_model.fit(X_train_no_outliers_rob)
#
#
# #create a column for the cluster
# df_rob_no['cluster'] = hi_model.labels_
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=df_rob_no)
#
# #make title
# plt.title('Hierarchical Clustering Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
#
# Z = linkage(X_train_no_outliers_rob, method='ward')
# #Z = linkage(X_train_no_outliers_rob, method='average')
# dendrogram(Z, labels=y_train_no_outliers_rob)
# plt.title('Hierarichical Clustering Dendogram RobustScaler N/O')
# plt.xlabel('Samples')
# plt.ylabel('Distance')
#
# print("Hierarchical Clustering-Agglomerative NMI Score for RobustScaler No Outliers",
#       normalized_mutual_info_score(y_train_no_outliers_rob, df_rob_no['cluster']))

# %% [markdown]
# ### PowerTransformer HC

# %% [markdown]
# #create a heirarchical clustering model
# from sklearn.cluster import AgglomerativeClustering
# from scipy.cluster.hierarchy import dendrogram, linkage
#
# #find the optimal number of clusters
# n_clusters = range(2, 10)
# models = [AgglomerativeClustering(n).fit(X_train_pow) for n in n_clusters]
#
# #plot the silhouette scores
# from sklearn.metrics import silhouette_score
# scores = [silhouette_score(X_train_pow, m.labels_) for m in models]
# plt.plot(n_clusters, scores, color='black')
# plt.xlabel('n_clusters')
# plt.ylabel('score')
# plt.grid()
# plt.show()
#
# for i, clust_num in enumerate(n_clusters):
#     mean_score = scores[i].mean()
#     print(f"Cluster {clust_num}: Mean Silhouette Score: {mean_score}")
#
# #create the model
# hi_model = AgglomerativeClustering(n_clusters=2)
# #hi_model = AgglomerativeClustering(n_clusters=3)
#
# #fit the model
# transformed_pow = hi_model.fit(X_train_pow)
#
# #create a column for the cluster
# df_pow['cluster'] = hi_model.labels_
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=df_pow)
#
# #make title
# plt.title('Hierarchical Clustering Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
# Z = linkage(X_train_pow, method='ward')
# #Z = linkage(X_train_pow, method='average')
# dendrogram(Z, labels=train_y.values)
# plt.title('Hierarchical Clustering Dendogram PowerTransformer')
# plt.xlabel('Samples')
# plt.ylabel('Distance')
#
# print("Hierarchical Clustering-Agglomerative NMI Score for PowerTransformer",
#       normalized_mutual_info_score(train_y, df_pow['cluster']))

# %% [markdown]
# ### PowerTransformer No Outliers HC

# %% [markdown]
# #create a heirarchical clustering model
# from sklearn.cluster import AgglomerativeClustering
# from scipy.cluster.hierarchy import dendrogram, linkage
# from sklearn.metrics.cluster import normalized_mutual_info_score
#
# #find the optimal number of clusters
# n_clusters = range(2, 10)
# models = [AgglomerativeClustering(n).fit(X_train_no_outliers_pow) for n in n_clusters]
#
# #plot the silhouette scores
# from sklearn.metrics import silhouette_score
# scores = [silhouette_score(X_train_no_outliers_pow, m.labels_) for m in models]
# plt.plot(n_clusters, scores, color='black')
# plt.xlabel('n_clusters')
# plt.ylabel('score')
# plt.grid()
# plt.show()
#
# for i, clust_num in enumerate(n_clusters):
#     mean_score = scores[i].mean()
#     print(f"Cluster {clust_num}: Mean Silhouette Score: {mean_score}")
#
# #create the model
# hi_model = AgglomerativeClustering(n_clusters=2)
# #hi_model = AgglomerativeClustering(n_clusters=3)
#
# #fit the model
# hi_model.fit(X_train_no_outliers_pow)
#
# #create a column for the cluster
# df_pow_no['cluster'] = hi_model.labels_
#
# #create a scatterplot of the data
# sns.scatterplot(x='PC1', y='PC2', hue='cluster', data=df_pow_no)
#
# #make title
# plt.title('Hierarchical Clustering Scatterplot')
# plt.grid()
# #add lines to thicken the 0 lines
# plt.axhline(0, color='black')
# plt.axvline(0, color='black')
#
# #show the plot
# plt.show()
#
# Z = linkage(X_train_no_outliers_pow, method='ward')
# #Z = linkage(X_train_no_outliers_pow, method='average')
# dendrogram(Z, labels=y_train_no_outliers_pow)
# plt.title('Hierarchical Clustering Dendogram PowerTransformer')
# plt.xlabel('Samples')
# plt.ylabel('Distance')
#
# print("Hierarchical Clustering-Agglomerative NMI Score for PowerTransformer No Outliers",
#       normalized_mutual_info_score(y_train_no_outliers_pow, df_pow_no['cluster']))

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ### RobustScaler Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

log_model = LogisticRegression()
log_model.get_params()

pca = PCA(n_components = best_comp_rob)
transformed_rob = pca.fit_transform(X_train_rob)

log_model.fit(transformed_rob, train_y)

transformed_test = pca.transform(X_test_rob)

predictions_rob = log_model.predict(transformed_test)

cm_rob = confusion_matrix(test_y, predictions_rob, labels=log_model.classes_)
disp = ConfusionMatrixDisplay(cm_rob, display_labels=log_model.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predictions_rob)
print(f'Accuracy:{accuracy}')
print(classification_report(test_y, predictions_rob, labels=log_model.classes_))
# Out:
# C:\Users\tessa\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy:0.8620689655172413
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.85        27
#            1       0.85      0.90      0.88        31
#
#     accuracy                           0.86        58
#    macro avg       0.86      0.86      0.86        58
# weighted avg       0.86      0.86      0.86        58

# %% [markdown]
# ### RobustScaler No Outliers Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

log_model = LogisticRegression()
log_model.get_params()

pca = PCA(n_components = best_comp_rob)
transformed_rob = pca.fit_transform(X_train_no_outliers_rob)

log_model.fit(transformed_rob, y_train_no_outliers_rob)
transformed_test = pca.transform(X_test_rob)

predictions_rob_no = log_model.predict(transformed_test)

cm_rob = confusion_matrix(test_y, predictions_rob_no, labels=log_model.classes_)
disp = ConfusionMatrixDisplay(cm_rob, display_labels=log_model.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predictions_rob_no)
print(f'Accuracy:{accuracy}')
print(classification_report(test_y, predictions_rob_no, labels=log_model.classes_))
# Out:
# Accuracy:0.8620689655172413
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.85        27
#            1       0.85      0.90      0.88        31
#
#     accuracy                           0.86        58
#    macro avg       0.86      0.86      0.86        58
# weighted avg       0.86      0.86      0.86        58

# %% [markdown]
# ### PowerTransformer Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

log_model = LogisticRegression()
log_model.get_params()

pca = PCA(n_components = best_comp_rob)
transformed_pow = pca.fit_transform(X_train_pow)

log_model.fit(transformed_pow, train_y)
transformed_test = pca.transform(X_test_pow)

predictions_pow = log_model.predict(transformed_test)

cm_rob = confusion_matrix(test_y, predictions_pow, labels=log_model.classes_)
disp = ConfusionMatrixDisplay(cm_rob, display_labels=log_model.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predictions_pow)
print(f'Accuracy:{accuracy}')
print(classification_report(test_y, predictions_pow, labels=log_model.classes_))
# Out:
# C:\Users\tessa\anaconda3\lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy:0.896551724137931
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        27
#            1       0.90      0.90      0.90        31
#
#     accuracy                           0.90        58
#    macro avg       0.90      0.90      0.90        58
# weighted avg       0.90      0.90      0.90        58

# %% [markdown]
# ### PowerTransformer No Outliers Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

log_model = LogisticRegression()
log_model.get_params()

pca = PCA(n_components = best_comp_rob)
transformed_pow = pca.fit_transform(X_train_no_outliers_pow)

log_model.fit(transformed_pow, y_train_no_outliers_pow)
transformed_test = pca.transform(X_test_pow)

predictions_pow_no = log_model.predict(transformed_test)

cm_rob = confusion_matrix(test_y, predictions_pow_no, labels=log_model.classes_)
disp = ConfusionMatrixDisplay(cm_rob, display_labels=log_model.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predictions_pow_no)
print(f'Accuracy:{accuracy}')
print(classification_report(test_y, predictions_pow_no, labels=log_model.classes_))
# Out:
# Accuracy:0.896551724137931
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        27
#            1       0.90      0.90      0.90        31
#
#     accuracy                           0.90        58
#    macro avg       0.90      0.90      0.90        58
# weighted avg       0.90      0.90      0.90        58

# %% [markdown]
# # Decision Trees

# %% [markdown]
# ### RobustScaler Decision Tree

# %%
# create a decision tree based on the train set
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# create a decision tree classifier and PCA
dt = DecisionTreeClassifier(random_state=42)
dt.get_params()
pca = PCA(n_components = best_comp_rob)
transformed_rob = pca.fit_transform(X_train_rob)

# fit the model
dt.fit(transformed_rob, train_y)
transformed_test = pca.transform(X_test_rob)

predict_rob_test = dt.predict(transformed_test)

accuracy = accuracy_score(test_y, predict_rob_test)
print(f'Accuracy of original model: {accuracy}')
# Out:
# Accuracy of original model: 0.9655172413793104

# %%
from sklearn.model_selection import cross_val_score
# Finding the best max depth and best max features this is modified code from the handouts.
dep, dscores =[], []
for d in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_depth=d)    
    dep.append(d)
    dscores.append(np.mean(cross_val_score(dt, transformed_rob, train_y, scoring='accuracy', cv=10)))
    print(f'Depth:{d} and Scores:{dscores[-1]}')

feat, fscores =[], []
for f in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_features=f)    
    feat.append(f)
    fscores.append(np.mean(cross_val_score(dt, transformed_rob, train_y, scoring='accuracy', cv=10)))
    print(f'Feature:{f} and Scores:{fscores[-1]}')
    

plt.plot(dep, dscores, color='black')
plt.xlabel('Depth')
plt.ylabel('Score')
plt.grid()
plt.show()

plt.plot(feat, fscores, color='black')
plt.xlabel('Feature')
plt.ylabel('Score')
plt.grid()
plt.show()
# Out:
# Depth:1 and Scores:0.75
# Depth:2 and Scores:0.7493464052287581
# Depth:3 and Scores:0.8245098039215686
# Depth:4 and Scores:0.8238562091503269
# Depth:5 and Scores:0.8464052287581699
# Depth:6 and Scores:0.8522875816993464
# Depth:7 and Scores:0.8467320261437908
# Depth:8 and Scores:0.8467320261437908
# Depth:9 and Scores:0.8467320261437908
# Depth:10 and Scores:0.8467320261437908
# Depth:11 and Scores:0.8467320261437908
# Depth:12 and Scores:0.8467320261437908
# Depth:13 and Scores:0.8467320261437908
# Depth:14 and Scores:0.8467320261437908
# Depth:15 and Scores:0.8467320261437908
# Depth:16 and Scores:0.8467320261437908
# Depth:17 and Scores:0.8467320261437908
# Depth:18 and Scores:0.8467320261437908
# Depth:19 and Scores:0.8467320261437908
# Depth:20 and Scores:0.8467320261437908
# Depth:21 and Scores:0.8467320261437908
# Depth:22 and Scores:0.8467320261437908
# Feature:1 and Scores:0.8248366013071896
# Feature:2 and Scores:0.7790849673202616
# Feature:3 and Scores:0.8473856209150327
# Feature:4 and Scores:0.8529411764705882
# Feature:5 and Scores:0.8405228758169935
# Feature:6 and Scores:0.8352941176470589
# Feature:7 and Scores:0.823529411764706
# Feature:8 and Scores:0.8408496732026144
# Feature:9 and Scores:0.8594771241830065
# Feature:10 and Scores:0.8584967320261437
# Feature:11 and Scores:0.8470588235294118
# Feature:12 and Scores:0.85359477124183
# Feature:13 and Scores:0.8245098039215686
# Feature:14 and Scores:0.8588235294117647
# Feature:15 and Scores:0.8522875816993464
# Feature:16 and Scores:0.8238562091503268
# Feature:17 and Scores:0.8640522875816993
# Feature:18 and Scores:0.8637254901960784
# Feature:19 and Scores:0.8300653594771241
# Feature:20 and Scores:0.8751633986928103
# Feature:21 and Scores:0.8751633986928103
# Feature:22 and Scores:0.8467320261437908

# %%
from sklearn.tree import plot_tree, export_text

#Plotting the decision tree with the best max depth.
plt.figure(figsize =(80,20))

transformed_rob = pca.fit_transform(X_train_rob)

dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_rob, train_y)

plt.figure(figsize=(10,10))
plot_tree(dt, filled=True, rounded=True, class_names=[str(i) for i in dt.classes_],
                                                      feature_names=[f'PC{i}' for i in range(1, pca.n_components_ + 1)])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_rob, train_y)

predict_rob_test = dt.predict(transformed_test)

cm_rob = confusion_matrix(test_y, predict_rob_test, labels=dt.classes_)
disp = ConfusionMatrixDisplay(cm_rob, display_labels=dt.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predict_rob_test)
print(f'Accuracy of tuned model:{accuracy}')
# Out:
# Accuracy of tuned model:0.9137931034482759

# %% [markdown]
# ### RobustScaler No Outliers Decision Tree

# %%
# create a decision tree based on the train set
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# create a decision tree classifier and PCA
dt = DecisionTreeClassifier(random_state=42)
dt.get_params()
pca = PCA(n_components = best_comp_rob_no)

transformed_rob_no = pca.fit_transform(X_train_no_outliers_rob)

# fit the model
dt.fit(transformed_rob_no, y_train_no_outliers_rob)
transformed_test = pca.transform(X_test_rob)

predictions_rob_no = dt.predict(transformed_test)

accuracy = accuracy_score(test_y, predictions_rob_no)
accuracy
# Out:
# 0.9310344827586207

# %%
from sklearn.model_selection import cross_val_score
# Finding the best max depth this is modified code from the handouts.
dep, scores =[], []
for d in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_depth=d)    
    dep.append(d)
    scores.append(np.mean(cross_val_score(dt, transformed_rob_no, y_train_no_outliers_rob, scoring='accuracy', cv=10)))
    print(f'Depth:{d} and Scores:{scores[-1]}')
    
feat, fscores =[], []
for f in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_features=f)    
    feat.append(f)
    fscores.append(np.mean(cross_val_score(dt, transformed_rob_no, y_train_no_outliers_rob, scoring='accuracy', cv=10)))
    print(f'Feature:{f} and Scores:{fscores[-1]}')
    

plt.plot(dep, dscores, color='black')
plt.xlabel('Depth')
plt.ylabel('Score')
plt.grid()
plt.show()

plt.plot(feat, fscores, color='black')
plt.xlabel('Feature')
plt.ylabel('Score')
plt.grid()
plt.show()
# Out:
# Depth:1 and Scores:0.7526143790849673
# Depth:2 and Scores:0.718627450980392
# Depth:3 and Scores:0.7875816993464053
# Depth:4 and Scores:0.8392156862745097
# Depth:5 and Scores:0.8156862745098039
# Depth:6 and Scores:0.8450980392156863
# Depth:7 and Scores:0.8558823529411764
# Depth:8 and Scores:0.8624183006535947
# Depth:9 and Scores:0.8624183006535947
# Depth:10 and Scores:0.8624183006535947
# Depth:11 and Scores:0.8624183006535947
# Depth:12 and Scores:0.8624183006535947
# Depth:13 and Scores:0.8624183006535947
# Depth:14 and Scores:0.8624183006535947
# Depth:15 and Scores:0.8624183006535947
# Depth:16 and Scores:0.8624183006535947
# Depth:17 and Scores:0.8624183006535947
# Depth:18 and Scores:0.8624183006535947
# Depth:19 and Scores:0.8624183006535947
# Depth:20 and Scores:0.8624183006535947
# Depth:21 and Scores:0.8624183006535947
# Depth:22 and Scores:0.8624183006535947
# Feature:1 and Scores:0.8222222222222223
# Feature:2 and Scores:0.8042483660130719
# Feature:3 and Scores:0.8058823529411765
# Feature:4 and Scores:0.8281045751633986
# Feature:5 and Scores:0.8169934640522876
# Feature:6 and Scores:0.8683006535947712
# Feature:7 and Scores:0.8326797385620915
# Feature:8 and Scores:0.8516339869281045
# Feature:9 and Scores:0.873529411764706
# Feature:10 and Scores:0.8336601307189543
# Feature:11 and Scores:0.8454248366013072
# Feature:12 and Scores:0.8287581699346405
# Feature:13 and Scores:0.8673202614379084
# Feature:14 and Scores:0.8457516339869281
# Feature:15 and Scores:0.8330065359477125
# Feature:16 and Scores:0.7928104575163399
# Feature:17 and Scores:0.8339869281045751
# Feature:18 and Scores:0.862091503267974
# Feature:19 and Scores:0.8385620915032679
# Feature:20 and Scores:0.8509803921568627
# Feature:21 and Scores:0.8160130718954248
# Feature:22 and Scores:0.8624183006535947

# %%
from sklearn.tree import plot_tree, export_text

#Plotting the decision tree with the best max depth.
plt.figure(figsize =(80,20))

transformed_rob_no = pca.fit_transform(X_train_no_outliers_rob)

dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(scores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_rob_no, y_train_no_outliers_rob)

plt.figure(figsize=(10,10))
plot_tree(dt, filled=True, rounded=True, class_names=[str(i) for i in dt.classes_],
                                                      feature_names=[f'PC{i}' for i in range(1, pca.n_components_ + 1)])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_rob_no, y_train_no_outliers_rob)

predictions_rob_no = dt.predict(transformed_test)

cm_rob_no = confusion_matrix(test_y, predictions_rob_no, labels=dt.classes_)
disp = ConfusionMatrixDisplay(cm_rob_no, display_labels=dt.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predictions_rob_no)
print(f'Accuracy of tuned model:{accuracy}')
# Out:
# Accuracy of tuned model:0.9482758620689655

# %% [markdown]
# ### PowerTransformer Decision Tree

# %%
# create a decision tree based on the train set
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# create a decision tree classifier and PCA
dt = DecisionTreeClassifier(random_state=42)
dt.get_params()

pca = PCA(n_components = best_comp_pow)

transformed_pow = pca.fit_transform(X_train_pow)

# fit the model
dt.fit(transformed_pow, train_y)
transformed_test = pca.transform(X_test_pow)

predict_pow_test = dt.predict(transformed_test)

accuracy = accuracy_score(test_y, predict_pow_test)
print(f'Accuracy of original model: {accuracy}')
# Out:
# Accuracy of original model: 0.8620689655172413

# %%
from sklearn.model_selection import cross_val_score
# Finding the best max depth and best max features this is modified code from the handouts.
dep, dscores =[], []
for d in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_depth=d)    
    dep.append(d)
    dscores.append(np.mean(cross_val_score(dt, transformed_pow, train_y, scoring='accuracy', cv=10)))
    print(f'Depth:{d} and Scores:{dscores[-1]}')

feat, fscores =[], []
for f in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_features=f)    
    feat.append(f)
    fscores.append(np.mean(cross_val_score(dt, transformed_pow, train_y, scoring='accuracy', cv=10)))
    print(f'Feature:{f} and Scores:{fscores[-1]}')
    

plt.plot(dep, dscores, color='black')
plt.xlabel('Depth')
plt.ylabel('Score')
plt.grid()
plt.show()

plt.plot(feat, fscores, color='black')
plt.xlabel('Feature')
plt.ylabel('Score')
plt.grid()
plt.show()
# Out:
# Depth:1 and Scores:0.7444444444444446
# Depth:2 and Scores:0.8071895424836601
# Depth:3 and Scores:0.7839869281045752
# Depth:4 and Scores:0.8300653594771242
# Depth:5 and Scores:0.8529411764705882
# Depth:6 and Scores:0.8584967320261437
# Depth:7 and Scores:0.8640522875816995
# Depth:8 and Scores:0.8640522875816995
# Depth:9 and Scores:0.8584967320261437
# Depth:10 and Scores:0.8584967320261437
# Depth:11 and Scores:0.8584967320261437
# Depth:12 and Scores:0.8584967320261437
# Depth:13 and Scores:0.8584967320261437
# Depth:14 and Scores:0.8584967320261437
# Depth:15 and Scores:0.8584967320261437
# Depth:16 and Scores:0.8584967320261437
# Depth:17 and Scores:0.8584967320261437
# Depth:18 and Scores:0.8584967320261437
# Depth:19 and Scores:0.8584967320261437
# Depth:20 and Scores:0.8584967320261437
# Depth:21 and Scores:0.8584967320261437
# Depth:22 and Scores:0.8584967320261437
# Feature:1 and Scores:0.800326797385621
# Feature:2 and Scores:0.8294117647058823
# Feature:3 and Scores:0.7895424836601306
# Feature:4 and Scores:0.8859477124183007
# Feature:5 and Scores:0.8921568627450981
# Feature:6 and Scores:0.8862745098039216
# Feature:7 and Scores:0.857516339869281
# Feature:8 and Scores:0.8813725490196079
# Feature:9 and Scores:0.8921568627450981
# Feature:10 and Scores:0.8584967320261437
# Feature:11 and Scores:0.858496732026144
# Feature:12 and Scores:0.8637254901960784
# Feature:13 and Scores:0.8915032679738563
# Feature:14 and Scores:0.8807189542483659
# Feature:15 and Scores:0.8980392156862745
# Feature:16 and Scores:0.9094771241830065
# Feature:17 and Scores:0.8532679738562091
# Feature:18 and Scores:0.8647058823529413
# Feature:19 and Scores:0.8470588235294116
# Feature:20 and Scores:0.8637254901960784
# Feature:21 and Scores:0.8633986928104577
# Feature:22 and Scores:0.8584967320261437

# %%
from sklearn.tree import plot_tree, export_text

#Plotting the decision tree with the best max depth.
plt.figure(figsize =(80,20))

transformed_pow = pca.fit_transform(X_train_pow)

dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_pow, train_y)

plt.figure(figsize=(10,10))
plot_tree(dt, filled=True, rounded=True, class_names=[str(i) for i in dt.classes_],
                                                      feature_names=[f'PC{i}' for i in range(1, pca.n_components_ + 1)])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_pow, train_y)

predict_pow_test = dt.predict(transformed_test)

cm_pow = confusion_matrix(test_y, predict_pow_test, labels=dt.classes_)
disp = ConfusionMatrixDisplay(cm_pow, display_labels=dt.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predict_pow_test)
print(f'Accuracy of tuned model:{accuracy}')
# Out:
# Accuracy of tuned model:0.8620689655172413

# %% [markdown]
# ### PowerTransformer No Outliers Decision Tree

# %%
# create a decision tree based on the train set
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# create a decision tree classifier and PCA
dt = DecisionTreeClassifier(random_state=42)
dt.get_params()

pca = PCA(n_components = best_comp_pow_no)

transformed_pow_no = pca.fit_transform(X_train_no_outliers_pow)

# fit the model
dt.fit(transformed_pow_no, y_train_no_outliers_pow)
transformed_test = pca.transform(X_test_pow)

predict_pow_test = dt.predict(transformed_test)

accuracy = accuracy_score(test_y, predict_pow_test)
print(f'Accuracy of original model: {accuracy}')
# Out:
# Accuracy of original model: 0.9482758620689655

# %%
from sklearn.model_selection import cross_val_score
# Finding the best max depth and best max features this is modified code from the handouts.
dep, dscores =[], []
for d in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_depth=d)    
    dep.append(d)
    dscores.append(np.mean(cross_val_score(dt, transformed_pow_no, y_train_no_outliers_pow, scoring='accuracy', cv=10)))
    print(f'Depth:{d} and Scores:{dscores[-1]}')

feat, fscores =[], []
for f in range(1,23):
    dt = DecisionTreeClassifier(random_state=42, max_features=f)    
    feat.append(f)
    fscores.append(np.mean(cross_val_score(dt, transformed_pow_no, y_train_no_outliers_pow, scoring='accuracy', cv=10)))
    print(f'Feature:{f} and Scores:{fscores[-1]}')
    

plt.plot(dep, dscores, color='black')
plt.xlabel('Depth')
plt.ylabel('Score')
plt.grid()
plt.show()

plt.plot(feat, fscores, color='black')
plt.xlabel('Feature')
plt.ylabel('Score')
plt.grid()
plt.show()
# Out:
# Depth:1 and Scores:0.7643790849673203
# Depth:2 and Scores:0.8222222222222222
# Depth:3 and Scores:0.8281045751633987
# Depth:4 and Scores:0.8565359477124185
# Depth:5 and Scores:0.8447712418300654
# Depth:6 and Scores:0.827124183006536
# Depth:7 and Scores:0.8330065359477125
# Depth:8 and Scores:0.8215686274509804
# Depth:9 and Scores:0.8215686274509804
# Depth:10 and Scores:0.8215686274509804
# Depth:11 and Scores:0.8215686274509804
# Depth:12 and Scores:0.8215686274509804
# Depth:13 and Scores:0.8215686274509804
# Depth:14 and Scores:0.8215686274509804
# Depth:15 and Scores:0.8215686274509804
# Depth:16 and Scores:0.8215686274509804
# Depth:17 and Scores:0.8215686274509804
# Depth:18 and Scores:0.8215686274509804
# Depth:19 and Scores:0.8215686274509804
# Depth:20 and Scores:0.8215686274509804
# Depth:21 and Scores:0.8215686274509804
# Depth:22 and Scores:0.8215686274509804
# Feature:1 and Scores:0.8686274509803923
# Feature:2 and Scores:0.8565359477124183
# Feature:3 and Scores:0.8179738562091504
# Feature:4 and Scores:0.8493464052287582
# Feature:5 and Scores:0.8797385620915034
# Feature:6 and Scores:0.8797385620915034
# Feature:7 and Scores:0.8732026143790849
# Feature:8 and Scores:0.9022875816993464
# Feature:9 and Scores:0.9192810457516339
# Feature:10 and Scores:0.8741830065359478
# Feature:11 and Scores:0.8686274509803923
# Feature:12 and Scores:0.8617647058823529
# Feature:13 and Scores:0.9016339869281046
# Feature:14 and Scores:0.8627450980392156
# Feature:15 and Scores:0.8843137254901962
# Feature:16 and Scores:0.8901960784313726
# Feature:17 and Scores:0.8624183006535949
# Feature:18 and Scores:0.8794117647058822
# Feature:19 and Scores:0.8388888888888888
# Feature:20 and Scores:0.872875816993464
# Feature:21 and Scores:0.8392156862745098
# Feature:22 and Scores:0.8215686274509804

# %%
from sklearn.tree import plot_tree, export_text

#Plotting the decision tree with the best max depth.
plt.figure(figsize =(80,20))

transformed_pow_no = pca.fit_transform(X_train_no_outliers_pow)

dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_pow_no, y_train_no_outliers_pow)

plt.figure(figsize=(10,10))
plot_tree(dt, filled=True, rounded=True, class_names=[str(i) for i in dt.classes_],
                                                      feature_names=[f'PC{i}' for i in range(1, pca.n_components_ + 1)])
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1, max_features=np.argmax(fscores))
dt = DecisionTreeClassifier(random_state=42, max_depth=np.argmax(dscores) + 1)
#dt = DecisionTreeClassifier(random_state=42, max_features=np.argmax(fscores))

dt.fit(transformed_pow_no, y_train_no_outliers_pow)

predict_pow_test_no = dt.predict(transformed_test)

cm_pow = confusion_matrix(test_y, predict_pow_test_no, labels=dt.classes_)
disp = ConfusionMatrixDisplay(cm_pow, display_labels=dt.classes_)
disp.plot()
plt.show()

accuracy = accuracy_score(test_y, predict_pow_test)
print(f'Accuracy of tuned model:{accuracy}')
# Out:
# Accuracy of tuned model:0.9482758620689655

# %% [markdown]
# ## Support Vector Models

# %% [markdown]
# ### RobustScaler SVM

# %% [markdown]
# ### RobustScaler No Outliers SVM

# %% [markdown]
# ### PowerTransformer SVM

# %% [markdown]
# ### PowerTransformer No Outliers SVM
