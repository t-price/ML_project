# %% [markdown]
# # Data Exploration

# %% [markdown]
# #### Data exploration to get to know the data better. You might use descriptive statistics and investigate correlations between features, generate some visualization plots. Use only the training set for this.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_X = pd.read_csv('train_X.csv')
display(train_X)
train_y = pd.read_csv('train_y.csv')
display(train_y)

#test_X = pd.read_csv('test_X.csv')
#display(test_X)
#test_y = pd.read_csv('test_y.csv')
#display(test_y)
#val_X = pd.read_csv('val_X.csv')
#display(val_X)
#val_y = pd.read_csv('val_y.csv')
#display(val_y)
# Out:
#     MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0       228.969       239.541       113.201         0.00238          0.000010
# 1       116.682       131.111       111.555         0.01050          0.000090
# 2       110.739       113.597       100.139         0.00356          0.000030
# 3       128.940       479.697        88.251         0.00581          0.000050
# 4       149.689       160.368       133.608         0.00257          0.000020
# 5       202.266       211.604       197.079         0.00180          0.000009
# 6        95.730       132.068        91.754         0.00551          0.000060
# 7       209.144       237.494       109.379         0.00282          0.000010
# 8       237.323       243.709       229.256         0.00303          0.000010
# 9       199.228       209.512       192.091         0.00241          0.000010
# 10      176.281       227.381       125.610         0.00520          0.000030
# ...

# %%
# make a scatterplot matrix of the data
import matplotlib.pyplot as plt
import seaborn as sns

# create a dataframe from training set
df = pd.concat([train_X, train_y], axis=1)

# create a pairplot of the data
sns.pairplot(df, hue='status')
plt.show()

# %%
new_parkinsons = parkinsons.drop(['name'], axis=1)
# create a correlation heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(new_parkinsons.corr(), annot=True, cmap='coolwarm')
plt.show()
